# %%
from bs4 import BeautifulSoup
import requests

# %%
url = 'https://en.wikipedia.org/wiki/List_of_largest_companies_by_revenue'
page = requests.get(url)
soup = BeautifulSoup(page.text, 'html')
table = soup.find_all('tr')[0]

# %%
world_titles = table.find_all('th')
world_table_titles = [title.text.strip() for title in world_titles]
print(world_table_titles)
# Out:
# ['Rank', 'Name', 'Industry', 'Revenue', 'Profit', 'Employees', 'Headquarters[note 1]', 'State-owned', 'Ref.', 'Revenue per worker']

# %%
world_table_titles[6] = 'Headquarters'

# %%
print(world_table_titles)
# Out:
# ['Rank', 'Name', 'Industry', 'Revenue', 'Profit', 'Employees', 'Headquarters', 'State-owned', 'Ref.', 'Revenue per worker']

# %%
import pandas as pd

# %%
df = pd.DataFrame(columns = world_table_titles)
df
# Out:
# Empty DataFrame
# Columns: [Rank, Name, Industry, Revenue, Profit, Employees, Headquarters, State-owned, Ref., Revenue per worker]
# Index: []

# %%
column_data = soup.find_all('tr')[:52]
for row in column_data[2:]:
    row_data = row.find_all('td')
    row_number = row.find_all('th')
    individual_row_data = []
    for data in row_number:
        individual_row_data.append(data.text.strip())  
    for data in row_data:
        individual_row_data.append(data.text.strip())   
    length = len(df)
    df.loc[length] = individual_row_data

# %%
df
# Out:
#    Rank                                     Name                Industry  \
# 0     1                                  Walmart                  Retail
# 1     2                             Saudi Aramco             Oil and gas
# 2     3                                   Amazon                  Retail
# 3     4          State Grid Corporation of China             Electricity
# 4     5                                    Vitol             Commodities
# 5     6     China National Petroleum Corporation             Oil and gas
# 6     7          China Petrochemical Corporation             Oil and gas
# 7     8                               ExxonMobil             Oil and gas
# 8     9                                    Apple             Electronics
# 9    10                                    Shell             Oil and gas
# 10   11                       UnitedHealth Group              Healthcare
# 11   12                               CVS Health              Healthcare
# ...

# %%
df.to_csv(r'C:\Users\libor\Downloads\Data Analysis\Companies.csv', index = False)
